# %% [markdown]
# ### Data Analysis with Pandas
#
# * Indexing
#     * The loc attribute allows indexing and slicing that always references the explicit index
#         * Label Indexing
#     * The iloc attribute allows indexing and slicing that always references the implicit index
#         * Integer Indexing
# * Grouping
# * Features
# * Filtering
# * Sorting
# * Statistical
# * Plotting
# * Saving

# %%
import pandas as pd
birds = pd.read_csv("https://raw.githubusercontent.com/APSSDC-Data-Analysis/DataAnalysis-7/main/Datasets/birds.csv")
birds.head()
# Out:
#    id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw type
# 0   0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84   SW
# 1   1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01   SW
# 2   2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34   SW
# 3   3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41   SW
# 4   4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13   SW

# %%
ind = pd.Index([34,56,768,89])
type(ind)
# Out:
# pandas.core.indexes.numeric.Int64Index

# %%
ind.tolist()
# Out:
# [34, 56, 768, 89]

# %%
birds[["huml","type"]]
# Out:
#       huml type
# 0    80.78   SW
# 1    88.91   SW
# 2    79.97   SW
# 3    77.65   SW
# 4    62.80   SW
# ..     ...  ...
# 415  17.96   SO
# 416  19.21   SO
# 417  18.79   SO
# 418  20.38   SO
# 419  17.89   SO
#
# [420 rows x 2 columns]

# %%
birds["humw"][0]
# Out:
# 6.68

# %%
birds[0:1]["humw"]
# Out:
# 0    6.68
# Name: humw, dtype: float64

# %% [markdown]
# ## Special index attributes
# ### Loc   -- used Label index  / explicit index / location and label
# ### Iloc  -- used integer index / implict indexing / location indexing

# %%
birds[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-305f12d01a1f> in <module>
# ----> 1 birds[0]
#
# ...

# %%
birds.iloc[0]
# Out:
# huml     80.78
# humw      6.68
# ulnal    72.01
# ulnaw     4.88
# feml     41.81
# femw       3.7
# tibl       5.5
# tibw      4.03
# tarl      38.7
# tarw      3.84
# type        SW
# Name: 0, dtype: object

# %%
birds.iloc[10:100:20]
# Out:
#     id    huml   humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl   tarw  \
# 10  10  165.00  11.45  156.00   8.68  80.25  7.85  143.00  8.25  86.61   6.63
# 30  30   75.05  12.55   44.05   8.62  75.31  6.76  112.60  7.22  34.31  14.09
# 50  50  171.00   8.39  187.00   6.68  58.67  6.70   87.57  6.34  50.44   8.41
# 70  70   26.63   1.63   27.19   1.72  12.21  1.02   31.56  1.07  21.62   0.83
# 90  90   75.94   5.25   80.66   4.26  30.94  2.85   68.23  2.97  37.38   2.47
#
#    type
# 10   SW
# 30   SW
# 50   SW
# 70   SW
# 90   SW

# %%
birds.loc[0,"type"]
# Out:
# 'SW'

# %%
birds.head()
# Out:
#    id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw type
# 0   0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84   SW
# 1   1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01   SW
# 2   2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34   SW
# 3   3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41   SW
# 4   4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13   SW

# %%
birds.loc[10:20,"type"]
# Out:
# 10    SW
# 11    SW
# 12    SW
# 13    SW
# 14    SW
# 15    SW
# 16    SW
# 17    SW
# 18    SW
# 19    SW
# 20    SW
# Name: type, dtype: object

# %%
birds.loc[1:20,["type","huml"]]
# Out:
#    type    huml
# 1    SW   88.91
# 2    SW   79.97
# 3    SW   77.65
# 4    SW   62.80
# 5    SW   61.92
# 6    SW   79.73
# 7    SW   86.98
# 8    SW  118.20
# 9    SW  145.00
# 10   SW  165.00
# 11   SW  186.00
# 12   SW  172.00
# 13   SW  148.91
# 14   SW  149.19
# 15   SW  140.59
# 16   SW  135.23
# 17   SW  124.53
# 18   SW  127.03
# 19   SW  106.02
# 20   SW  113.84

# %%
birds.loc[[1,100,50,200],["type","huml"]] # fancy slicing using loc
# Out:
#     type    huml
# id
# 1     SW   88.91
# 100   SW   67.06
# 50    SW  171.00
# 200    T   34.24

# %%
birds.at[200,"type"]  # at (where -- location -- accessing single value)
# Out:
# 'T'

# %%
birds.head()
# Out:
#    id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw type
# 0   0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84   SW
# 1   1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01   SW
# 2   2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34   SW
# 3   3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41   SW
# 4   4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13   SW

# %%
birds.shape
# Out:
# (420, 12)

# %%
birds.set_index('id', inplace = True) # if you want set any label as index 
# inplace = True --- ir changes original dataset

# %%
birds
# Out:
#       huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw type
# id
# 0    80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84   SW
# 1    88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01   SW
# 2    79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34   SW
# 3    77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41   SW
# 4    62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13   SW
# ..     ...   ...    ...    ...    ...   ...    ...   ...    ...   ...  ...
# 415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15   SO
# 416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15   SO
# 417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21   SO
# 418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24   SO
# 419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05   SO
#
# [420 rows x 11 columns]

# %%
birds.reset_index().head()
# Out:
#    id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw type
# 0   0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84   SW
# 1   1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01   SW
# 2   2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34   SW
# 3   3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41   SW
# 4   4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13   SW

# %% [markdown]
# # 5. Grouping

# %% [markdown]
# 1 file IPL
#
# having 1000+ records
#
# in between years 2010 - 2020
#
# CSK Team
#
# MI
#
# RCB
#
# KKR
#
# SRH
#
# RR
#
# wins
# outs
# runs
# overs

# %%
birds.tail()
# Out:
#       huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw type
# id
# 415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15   SO
# 416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15   SO
# 417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21   SO
# 418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24   SO
# 419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05   SO

# %%
birds.columns
# Out:
# Index(['huml', 'humw', 'ulnal', 'ulnaw', 'feml', 'femw', 'tibl', 'tibw',
#        'tarl', 'tarw', 'type'],
#       dtype='object')

# %%
birds["type"].uncounte()
# Out:
# array(['SW', 'W', 'T', 'R', 'P', 'SO'], dtype=object)

# %%
birds["type"].value_counts()
# Out:
# SO    128
# SW    116
# W      65
# R      50
# P      38
# T      23
# Name: type, dtype: int64

# %%
bird_grp = birds.groupby("type")   # ["type","huml"]
bird_grp

# %%
for name, grp_data in bird_grp:
    print(name, grp_data)
# Out:
# P       huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw type
# id
# 254  29.26  2.66  27.63   2.23  27.87  2.03  38.90  1.81  25.22  1.62    P
# 255  30.60  2.45  25.90   1.87  32.36  2.10  50.25  1.88  33.58  1.88    P
# 256  30.25  2.29  25.14   1.87  31.61  2.18  50.98  2.00  33.50  1.93    P
# 257  42.52  2.99  36.73   2.91  52.24  3.81  81.57  3.71  61.27  2.71    P
# 258  45.60  3.35  38.73   3.52  54.45  4.10  83.59  3.72  63.91  2.67    P
# 259  43.97  3.54  38.38   3.14  52.49  4.25  83.15  4.12  61.08  3.04    P
# 260  46.38  3.41  39.80   3.48  54.67  4.08  85.88  4.04  63.75  3.09    P
# 261  45.57  4.64  57.13   2.93  28.32  2.26  36.95  1.96  19.75  2.16    P
# 262  33.81  2.80  42.82   2.22  18.88  1.45  26.28  1.31  14.45  1.29    P
# 263  31.72  2.64  40.00   1.99  20.36  1.59  32.21  1.62  17.72  1.52    P
# 264   9.85  2.88  14.73   1.73  16.27  1.22  20.89  1.25   7.77  1.23    P
# ...

# %%
birds.head(1)
# Out:
#      huml  humw  ulnal  ulnaw   feml  femw  tibl  tibw  tarl  tarw type
# id
# 0   80.78  6.68  72.01   4.88  41.81   3.7   5.5  4.03  38.7  3.84   SW

# %%
bird_grp.first()  # FIRST record of very group
# Out:
#         huml  humw   ulnal  ulnaw   feml  femw    tibl  tibw    tarl  tarw
# type
# P      29.26  2.66   27.63   2.23  27.87  2.03   38.90  1.81   25.22  1.62
# R      63.76  4.74   69.06   4.08  57.33  4.88   75.67  4.33   60.19  3.82
# SO     29.61  2.41   33.93   2.02  30.79  2.19   51.64  2.01   37.33  1.78
# SW     80.78  6.68   72.01   4.88  41.81  3.70    5.50  4.03   38.70  3.84
# T      43.97  4.64   51.07   3.80  38.76  3.18   55.67  2.88   30.41  2.83
# W     157.00  9.00  192.00   7.02  85.60  6.44  227.00  6.84  175.00  6.77

# %%
bird_grp.last()
# Out:
#        huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw
# type
# P     41.60  3.74  56.50   3.02  37.00  2.99  62.90  2.82  38.21  2.51
# R     35.63  2.40  42.67   2.02  28.51  2.41  42.64  2.46  21.05  3.12
# SO    17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
# SW    98.73  6.48  91.69   5.31  35.34  4.02  92.36  4.46  50.53  2.69
# T     39.64  4.07  37.32   2.98  45.50  3.42  64.45  3.37  37.77  2.86
# W     87.01  5.18  94.34   4.45  35.73  2.80  67.12  2.93  43.43  2.34

# %%
bird_grp.get_group("W")  # accessing W bird data/ records
# Out:
#        huml   humw   ulnal  ulnaw    feml  femw    tibl  tibw    tarl  tarw
# id
# 116  157.00   9.00  192.00   7.02   85.60  6.44  227.00  6.84  175.00  6.77
# 117  190.00  11.92  225.00   8.55  101.75  7.75  240.00  7.71  175.00  7.00
# 118   70.01   3.71   76.90   2.88   49.42  3.08   79.56  3.35   52.74  3.02
# 119   92.93   5.28  110.94   3.87   55.11  4.16  137.00  4.29   96.37  3.79
# 120  118.52   6.87  134.91   5.06   78.20  5.24  132.00  5.38   85.28  4.74
# ..      ...    ...     ...    ...     ...   ...     ...   ...     ...   ...
# 176   33.20   2.11   34.31   2.25   20.36  1.57   37.95  1.42   23.67  1.26
# 177   32.31   2.16   32.74   1.98   19.05  1.40   33.37  1.14   21.20  1.00
# 178   28.51   1.80   29.35   1.78   17.60  1.21   36.04  1.14   20.81  0.83
# 179   34.12   1.90   35.57   1.93   21.22  1.39   46.24  1.27   31.39  1.05
# 180   87.01   5.18   94.34   4.45   35.73  2.80   67.12  2.93   43.43  2.34
#
# [65 rows x 10 columns]

# %%
bird_grp.get_group("W").mean()
# Out:
# huml     73.133077
# humw      4.607077
# ulnal    78.101385
# ulnaw     4.102615
# feml     40.119531
# femw      3.118594
# tibl     76.150000
# tibw      3.179231
# tarl     47.543385
# tarw      2.760308
# dtype: float64

# %%
bird_grp.get_group("W").sum()
# Out:
# huml     4753.65
# humw      299.46
# ulnal    5076.59
# ulnaw     266.67
# feml     2567.65
# femw      199.59
# tibl     4949.75
# tibw      206.65
# tarl     3090.32
# tarw      179.42
# dtype: float64

# %% [markdown]
# # 6. Features

# %% [markdown]
# labels/ columns / features
#
# 1 file
# Name   roll number internal marks   External mark
# dfb     456             56            NaN

# %%
birds.head()
# Out:
#      huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw type
# id
# 0   80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84   SW
# 1   88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01   SW
# 2   79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34   SW
# 3   77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41   SW
# 4   62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13   SW

# %%
 # add one more feature to already existing data
birds["len_type"]  =  birds["type"].str.len()
birds
# Out:
#       huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw type  \
# id
# 0    80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84   SW
# 1    88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01   SW
# 2    79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34   SW
# 3    77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41   SW
# 4    62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13   SW
# ..     ...   ...    ...    ...    ...   ...    ...   ...    ...   ...  ...
# 415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15   SO
# 416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15   SO
# 417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21   SO
# 418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24   SO
# 419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05   SO
#
#      len_type
# id
# 0           2
# 1           2
# ...

# %%
birds[birds.columns[:-2]].mean(axis = 1)
# Out:
# id
# 0      26.193
# 1      36.324
# 2      32.889
# 3      30.920
# 4      25.437
#         ...
# 415    11.579
# 416    12.303
# 417    12.410
# 418    13.386
# 419    11.244
# Length: 420, dtype: float64

# %%
birds["Mean_Features"] = birds[birds.columns[:-2]].mean(axis = 1)

# %%
birds
# Out:
#       huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw type  \
# id
# 0    80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84   SW
# 1    88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01   SW
# 2    79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34   SW
# 3    77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41   SW
# 4    62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13   SW
# ..     ...   ...    ...    ...    ...   ...    ...   ...    ...   ...  ...
# 415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15   SO
# 416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15   SO
# 417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21   SO
# 418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24   SO
# 419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05   SO
#
#      len_type  Mean_Features
# id
# ...

# %%
# add "huml	humw"   
birds["huml_and_humw"] = birds["huml"]+birds["humw"]
birds
# Out:
#       huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw type  \
# id
# 0    80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84   SW
# 1    88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01   SW
# 2    79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34   SW
# 3    77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41   SW
# 4    62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13   SW
# ..     ...   ...    ...    ...    ...   ...    ...   ...    ...   ...  ...
# 415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15   SO
# 416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15   SO
# 417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21   SO
# 418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24   SO
# 419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05   SO
#
#      len_type  Mean_Features  huml_and_humw
# id
# ...

# %%
birds[["huml","humw"]].sum(axis = 1)
# Out:
# id
# 0      87.46
# 1      95.54
# 2      86.34
# 3      83.35
# 4      67.64
#        ...
# 415    19.59
# 416    20.85
# 417    20.42
# 418    22.16
# 419    19.33
# Length: 420, dtype: float64

# %% [markdown]
# # 7. Filtering

# %%
# cleaning the data
# Extracting wanted data

# %%
birds.head()
# Out:
#      huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw type  \
# id
# 0   80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84   SW
# 1   88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01   SW
# 2   79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34   SW
# 3   77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41   SW
# 4   62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13   SW
#
#     len_type  Mean_Features  huml_and_humw
# id
# 0          2         26.193          87.46
# 1          2         36.324          95.54
# 2          2         32.889          86.34
# 3          2         30.920          83.35
# 4          2         25.437          67.64

# %%
birds.count()
# Out:
# huml             419
# humw             419
# ulnal            417
# ulnaw            418
# feml             418
# femw             419
# tibl             418
# tibw             419
# tarl             419
# tarw             419
# type             420
# len_type         420
# Mean_Features    420
# huml_and_humw    419
# dtype: int64

# %%
birds["humw"].max()
# Out:
# 17.84

# %%
birds["humw"].min()
# Out:
# 1.14

# %%
humw -- value -- 10 - 15

# %%
birds["humw"]>10  # bool array
# Out:
# id
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 415    False
# 416    False
# 417    False
# 418    False
# 419    False
# Name: humw, Length: 420, dtype: bool

# %%
birds[birds["humw"]>10]
# Out:
#        huml   humw   ulnal  ulnaw    feml   femw    tibl   tibw    tarl  \
# id
# 9    145.00  10.42  144.00   7.05   70.96   7.44  120.00   7.31   78.67
# 10   165.00  11.45  156.00   8.68   80.25   7.85  143.00   8.25   86.61
# 29    72.50  14.78   45.83  10.33   77.02   7.76  128.75   6.49   32.48
# 30    75.05  12.55   44.05   8.62   75.31   6.76  112.60   7.22   34.31
# 31   175.00  10.69  228.00   8.65   47.13   6.16   64.53   4.41   18.42
# 32   188.00  11.35  250.00   9.64   52.49   7.60   69.06   5.13   19.52
# 33   210.00  13.03  278.00  10.74   56.87   8.03   76.66   5.20   22.54
# 34   185.00  10.91  235.00   8.02   51.00   6.71   68.67   4.24   20.14
# 35   179.00  11.16  222.00   8.57   47.51   6.39   65.18   4.51   19.67
# 36   183.00  11.37  280.00   9.22   52.34   7.24   68.09   4.61   20.08
# 37   185.00  12.47  242.00   9.80   52.39   7.50   68.01   4.66   19.44
# 38   272.00  14.86  320.00  10.42   91.60   9.71  132.00  10.23   81.77
# ...

# %%
birds[(birds["humw"]>10)  |  (birds["humw"]<15)] 
# Logic gates   -- bitwise and operator 
# | or 
# & and
# Out:
#       huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw type  \
# id
# 0    80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84   SW
# 1    88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01   SW
# 2    79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34   SW
# 3    77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41   SW
# 4    62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13   SW
# ..     ...   ...    ...    ...    ...   ...    ...   ...    ...   ...  ...
# 415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15   SO
# 416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15   SO
# 417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21   SO
# 418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24   SO
# 419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05   SO
#
#      len_type  Mean_Features  huml_and_humw
# id
# ...

# %%
birds.head()
# Out:
#      huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw type  \
# id
# 0   80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84   SW
# 1   88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01   SW
# 2   79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34   SW
# 3   77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41   SW
# 4   62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13   SW
#
#     len_type  Mean_Features  huml_and_humw
# id
# 0          2         26.193          87.46
# 1          2         36.324          95.54
# 2          2         32.889          86.34
# 3          2         30.920          83.35
# 4          2         25.437          67.64

# %%
# P bird data 
birds[birds["type"]  == "P"]
# Out:
#       huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw type  \
# id
# 254  29.26  2.66  27.63   2.23  27.87  2.03  38.90  1.81  25.22  1.62    P
# 255  30.60  2.45  25.90   1.87  32.36  2.10  50.25  1.88  33.58  1.88    P
# 256  30.25  2.29  25.14   1.87  31.61  2.18  50.98  2.00  33.50  1.93    P
# 257  42.52  2.99  36.73   2.91  52.24  3.81  81.57  3.71  61.27  2.71    P
# 258  45.60  3.35  38.73   3.52  54.45  4.10  83.59  3.72  63.91  2.67    P
# 259  43.97  3.54  38.38   3.14  52.49  4.25  83.15  4.12  61.08  3.04    P
# 260  46.38  3.41  39.80   3.48  54.67  4.08  85.88  4.04  63.75  3.09    P
# 261  45.57  4.64  57.13   2.93  28.32  2.26  36.95  1.96  19.75  2.16    P
# 262  33.81  2.80  42.82   2.22  18.88  1.45  26.28  1.31  14.45  1.29    P
# 263  31.72  2.64  40.00   1.99  20.36  1.59  32.21  1.62  17.72  1.52    P
# 264   9.85  2.88  14.73   1.73  16.27  1.22  20.89  1.25   7.77  1.23    P
# ...

# %%
birds[(birds["type"]=="SW") | (birds["type"]=="R")]
# Out:
#       huml  humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl  tarw type  \
# id
# 0    80.78  6.68   72.01   4.88  41.81  3.70    5.50  4.03  38.70  3.84   SW
# 1    88.91  6.63   80.53   5.59  47.04  4.30   80.22  4.51  41.50  4.01   SW
# 2    79.97  6.37   69.26   5.28  43.07  3.90   75.35  4.04  38.31  3.34   SW
# 3    77.65  5.70   65.76   4.77  40.04  3.52   69.17  3.40  35.78  3.41   SW
# 4    62.80  4.84   52.09   3.73  33.95  2.72   56.27  2.96  31.88  3.13   SW
# ..     ...   ...     ...    ...    ...   ...     ...   ...    ...   ...  ...
# 249  93.37  5.33  102.65   3.90  58.55  4.62  101.24  4.57  71.30  4.38    R
# 250  99.69  6.09  111.00   4.26  60.84  4.75  104.72  4.92  71.23  4.21    R
# 251  34.84  2.44   40.68   2.04  38.43  2.54   42.48  2.45  20.07  3.15    R
# 252  33.12  2.40   39.85   1.80  27.46  2.19   38.99  2.15  19.10  2.89    R
# 253  35.63  2.40   42.67   2.02  28.51  2.41   42.64  2.46  21.05  3.12    R
#
# ...

# %% [markdown]
# # 8. Sorting

# %%
# Index sort 
birds.sort_index(axis = 1, ascending=True)  
# A-Z
# a-z
# Out:
#      Mean_Features   feml  femw   huml  huml_and_humw  humw  len_type   tarl  \
# id
# 0           26.193  41.81  3.70  80.78          87.46  6.68         2  38.70
# 1           36.324  47.04  4.30  88.91          95.54  6.63         2  41.50
# 2           32.889  43.07  3.90  79.97          86.34  6.37         2  38.31
# 3           30.920  40.04  3.52  77.65          83.35  5.70         2  35.78
# 4           25.437  33.95  2.72  62.80          67.64  4.84         2  31.88
# ..             ...    ...   ...    ...            ...   ...       ...    ...
# 415         11.579  18.36  1.54  17.96          19.59  1.63         2  21.99
# 416         12.303  19.24  1.45  19.21          20.85  1.64         2  23.60
# 417         12.410  20.96  1.43  18.79          20.42  1.63         2  22.86
# 418         13.386  21.35  1.48  20.38          22.16  1.78         2  25.98
# 419         11.244  17.62  1.34  17.89          19.33  1.44         2  21.69
#
# ...

# %%
birds.sort_index(axis = 0, ascending=False)
# Out:
#       huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw type  \
# id
# 419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05   SO
# 418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24   SO
# 417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21   SO
# 416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15   SO
# 415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15   SO
# ..     ...   ...    ...    ...    ...   ...    ...   ...    ...   ...  ...
# 4    62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13   SW
# 3    77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41   SW
# 2    79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34   SW
# 1    88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01   SW
# 0    80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84   SW
#
#      len_type  Mean_Features  huml_and_humw
# id
# ...

# %%
birds.sort_index(axis = 0, ascending=True)
# Out:
#       huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw type  \
# id
# 0    80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84   SW
# 1    88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01   SW
# 2    79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34   SW
# 3    77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41   SW
# 4    62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13   SW
# ..     ...   ...    ...    ...    ...   ...    ...   ...    ...   ...  ...
# 415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15   SO
# 416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15   SO
# 417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21   SO
# 418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24   SO
# 419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05   SO
#
#      len_type  Mean_Features  huml_and_humw
# id
# ...

# %%
birds.sort_values(by = "huml", ascending= False)
# Out:
#        huml   humw   ulnal  ulnaw    feml  femw    tibl   tibw    tarl   tarw  \
# id
# 58   420.00  17.84  422.00  11.72  110.54  9.99  237.00  11.03  128.35   8.93
# 56   310.00  14.40  315.00   9.51   88.77  8.10  180.00   9.45   96.13   7.69
# 60   300.00  12.48  300.00   8.65   84.05  8.53  178.00   9.61   99.01   7.55
# 38   272.00  14.86  320.00  10.42   91.60  9.71  132.00  10.23   81.77   8.91
# 39   270.00  14.25  310.00  10.90   86.20  9.96  125.76   9.63   79.18  10.05
# ..      ...    ...     ...    ...     ...   ...     ...    ...     ...    ...
# 367   13.31   1.17   16.47   1.06   12.32  0.93   22.47   0.95   15.97   0.75
# 413   12.95   1.16   14.09   1.03   13.03  1.03   22.13   0.96   15.19   1.02
# 377   12.69   1.69   17.44   1.16   11.83  1.03   23.80   0.87   16.97   0.66
# 264    9.85   2.88   14.73   1.73   16.27  1.22   20.89   1.25    7.77   1.23
# 342     NaN    NaN     NaN    NaN   32.54  2.65   55.06   2.81   38.94   2.25
#
# ...

# %%
 # sort multiple columns at a time
birds.sort_values(by = ["huml", "type"], ascending= False)
# Out:
#        huml   humw   ulnal  ulnaw    feml  femw    tibl   tibw    tarl   tarw  \
# id
# 58   420.00  17.84  422.00  11.72  110.54  9.99  237.00  11.03  128.35   8.93
# 56   310.00  14.40  315.00   9.51   88.77  8.10  180.00   9.45   96.13   7.69
# 60   300.00  12.48  300.00   8.65   84.05  8.53  178.00   9.61   99.01   7.55
# 38   272.00  14.86  320.00  10.42   91.60  9.71  132.00  10.23   81.77   8.91
# 39   270.00  14.25  310.00  10.90   86.20  9.96  125.76   9.63   79.18  10.05
# ..      ...    ...     ...    ...     ...   ...     ...    ...     ...    ...
# 367   13.31   1.17   16.47   1.06   12.32  0.93   22.47   0.95   15.97   0.75
# 413   12.95   1.16   14.09   1.03   13.03  1.03   22.13   0.96   15.19   1.02
# 377   12.69   1.69   17.44   1.16   11.83  1.03   23.80   0.87   16.97   0.66
# 264    9.85   2.88   14.73   1.73   16.27  1.22   20.89   1.25    7.77   1.23
# 342     NaN    NaN     NaN    NaN   32.54  2.65   55.06   2.81   38.94   2.25
#
# ...

# %%
help(birds.sort_index)
# Out:
# Help on method sort_index in module pandas.core.frame:
#
# sort_index(axis=0, level=None, ascending=True, inplace=False, kind='quicksort', na_position='last', sort_remaining=True, ignore_index: bool = False) method of pandas.core.frame.DataFrame instance
#     Sort object by labels (along an axis).
#
#     Parameters
#     ----------
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#         The axis along which to sort.  The value 0 identifies the rows,
#         and 1 identifies the columns.
#     level : int or level name or list of ints or list of level names
#         If not None, sort on values in specified index level(s).
#     ascending : bool, default True
#         Sort ascending vs. descending.
#     inplace : bool, default False
#         If True, perform operation in-place.
#     kind : {'quicksort', 'mergesort', 'heapsort'}, default 'quicksort'
#         Choice of sorting algorithm. See also ndarray.np.sort for more
# ...

# %% [markdown]
# # 9. Statistical

# %% [markdown]
# max value
# min
# mean
# median
# varience
# std dev
# sum
# count
# mode

# %%
birds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 420 entries, 0 to 419
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   huml           419 non-null    float64
#  1   humw           419 non-null    float64
#  2   ulnal          417 non-null    float64
#  3   ulnaw          418 non-null    float64
#  4   feml           418 non-null    float64
#  5   femw           419 non-null    float64
#  6   tibl           418 non-null    float64
#  7   tibw           419 non-null    float64
#  8   tarl           419 non-null    float64
#  9   tarw           419 non-null    float64
#  10  type           420 non-null    object
#  11  len_type       420 non-null    int64
#  12  Mean_Features  420 non-null    float64
#  13  huml_and_humw  419 non-null    float64
# dtypes: float64(12), int64(1), object(1)
# memory usage: 69.2+ KB

# %%
birds.describe()
# Out:
#              huml        humw       ulnal       ulnaw        feml        femw  \
# count  419.000000  419.000000  417.000000  418.000000  418.000000  419.000000
# mean    64.650501    4.370573   69.115372    3.597249   36.872416    3.220883
# std     53.834549    2.854617   58.784775    2.186747   19.979082    2.023581
# min      9.850000    1.140000   14.090000    1.000000   11.830000    0.930000
# 25%     25.170000    2.190000   28.050000    1.870000   21.297500    1.715000
# 50%     44.180000    3.500000   43.710000    2.945000   31.130000    2.520000
# 75%     90.310000    5.810000   97.520000    4.770000   47.120000    4.135000
# max    420.000000   17.840000  422.000000   12.000000  117.070000   11.640000
#
#              tibl        tibw        tarl        tarw    len_type  \
# count  418.000000  419.000000  419.000000  419.000000  420.000000
# mean    64.662823    3.182339   39.229976    2.930024    1.580952
# std     37.838145    2.080827   23.184313    2.185673    0.493992
# ...

# %%
birds["ulnal"].median()
# Out:
# 43.71

# %%
birds["ulnal"].mean()
# Out:
# 69.11537170263787

# %%
birds["type"].mode()  # frequency count of entire column
# Out:
# 0    SO
# dtype: object

# %%
birds["type"].value_counts()
# Out:
# SO    128
# SW    116
# W      65
# R      50
# P      38
# T      23
# Name: type, dtype: int64

# %%
birds["ulnal"].std()
# Out:
# 58.7847749488504

# %%
import numpy as np
birds[["ulnal"]].agg([np.min, np.max, np.mean])
# Out:
#            ulnal
# amin   14.090000
# amax  422.000000
# mean   69.115372

# %%
birds[["ulnal"]].max()
# Out:
# ulnal    422.0
# dtype: float64

# %%
birds["ulnal"].idxmax()  # find max value index position
# Out:
# 58

# %%
birds.iloc[58]
# Out:
# huml                420
# humw              17.84
# ulnal               422
# ulnaw             11.72
# feml             110.54
# femw               9.99
# tibl                237
# tibw              11.03
# tarl             128.35
# tarw               8.93
# type                 SW
# len_type              2
# Mean_Features    137.74
# huml_and_humw    437.84
# Name: 58, dtype: object

# %%
birds["ulnal"].idxmin()
# Out:
# 413

# %% [markdown]
# ## 10. Plotting
# ## 11. Saving

# %%
import matplotlib.pyplot as plt

# %%
birds.plot()

# %%
birds["Mean_Features"].plot()

# %%
birds.columns
# Out:
# Index(['huml', 'humw', 'ulnal', 'ulnaw', 'feml', 'femw', 'tibl', 'tibw',
#        'tarl', 'tarw', 'type', 'len_type', 'Mean_Features', 'huml_and_humw'],
#       dtype='object')

# %%
birds.describe()
# Out:
#              huml        humw       ulnal       ulnaw        feml        femw  \
# count  419.000000  419.000000  417.000000  418.000000  418.000000  419.000000
# mean    64.650501    4.370573   69.115372    3.597249   36.872416    3.220883
# std     53.834549    2.854617   58.784775    2.186747   19.979082    2.023581
# min      9.850000    1.140000   14.090000    1.000000   11.830000    0.930000
# 25%     25.170000    2.190000   28.050000    1.870000   21.297500    1.715000
# 50%     44.180000    3.500000   43.710000    2.945000   31.130000    2.520000
# 75%     90.310000    5.810000   97.520000    4.770000   47.120000    4.135000
# max    420.000000   17.840000  422.000000   12.000000  117.070000   11.640000
#
#              tibl        tibw        tarl        tarw    len_type  \
# count  418.000000  419.000000  419.000000  419.000000  420.000000
# mean    64.662823    3.182339   39.229976    2.930024    1.580952
# std     37.838145    2.080827   23.184313    2.185673    0.493992
# ...

# %%
birds.describe().to_csv("birds.csv")

# %%
birds.describe().to_excel("birds_describe.xlsx")

# %% [markdown]
# # Cleaning data in Python
#
#
# * NaN : not a number -- special floating-point value
# * Working with duplicates and missing values
#     * isnull()
#     * notnull()
#     * dropna()
#     * fillna()
#     * replace()
# * Which values should be replaced with missing values based on data identifying and eliminating outliers
#
# * Dropping duplicate data

# %% [markdown]
# 2 file
#
# first  file  100 records --  5 persons responded  useless file -- unwanted
# second file  100 records --  95 persons responded  -- will take --
#                                     filling missing with meaning fulldata

# %%
emp = pd.read_csv("https://raw.githubusercontent.com/APSSDC-Data-Analysis/DataAnalysis-7/main/Datasets/employe.csv")
emp.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
emp.shape  # 1000 employe details
# Out:
# (1000, 8)

# %%
emp.isnull().sum() # finding missing data
# Out:
# First Name            67
# Gender               145
# Start Date             0
# Last Login Time        0
# Salary                 0
# Bonus %                0
# Senior Management     67
# Team                  43
# dtype: int64

# %%
# notnull()
emp.notnull().sum()  # non null value count
# Out:
# First Name            933
# Gender                855
# Start Date           1000
# Last Login Time      1000
# Salary               1000
# Bonus %              1000
# Senior Management     933
# Team                  957
# dtype: int64

# %%
emp.describe()  # statastical
# Out:
#               Salary      Bonus %
# count    1000.000000  1000.000000
# mean    90662.181000    10.207555
# std     32923.693342     5.528481
# min     35013.000000     1.015000
# 25%     62613.000000     5.401750
# 50%     90428.000000     9.838500
# 75%    118740.250000    14.838000
# max    149908.000000    19.944000

# %%
emp.dropna().shape
# Out:
# (764, 8)

# %%
1000 - 764   # 236 are entired details with missing data
# Out:
# 236

# %%
emp.dropna() # it drops entire record having min one missing value
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 2        Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male  1/24/1998         4:47 PM  101004    1.389
# 5       Dennis    Male  4/18/1987         1:35 AM  115163   10.125
# ..         ...     ...        ...             ...     ...      ...
# 994     George    Male  6/21/2013         5:47 PM   98874    4.479
# 996    Phillip    Male  1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male  5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male  4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male  5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 2               False               Finance
# ...

# %%
emp["First Name"].isnull().sum()
# Out:
# 67

# %%
# fillna() -- replacing null values with given data

emp["Gender"].fillna("No Gender")  # filling with constant
# Out:
# 0           Male
# 1           Male
# 2         Female
# 3           Male
# 4           Male
#          ...
# 995    No Gender
# 996         Male
# 997         Male
# 998         Male
# 999         Male
# Name: Gender, Length: 1000, dtype: object

# %%
emp["Gender"].fillna(0)
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3        Male
# 4        Male
#         ...
# 995         0
# 996      Male
# 997      Male
# 998      Male
# 999      Male
# Name: Gender, Length: 1000, dtype: object

# %%
# bfill   -- backword one -- filling next one detils 
# and pad --  forword one -- filling missing value with previoue one 
emp["Gender"].fillna(method = "pad")
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3        Male
# 4        Male
#         ...
# 995      Male
# 996      Male
# 997      Male
# 998      Male
# 999      Male
# Name: Gender, Length: 1000, dtype: object

# %%
emp["Gender"].fillna(method = "bfill")
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3        Male
# 4        Male
#         ...
# 995      Male
# 996      Male
# 997      Male
# 998      Male
# 999      Male
# Name: Gender, Length: 1000, dtype: object
